# %%
from numpy import array
from keras.models import Sequentialquential
from keras.layers import Dense

# %%
X = array([[10, 20, 30], [20, 30, 40], [30, 40, 50], [40, 50, 60]])
y = array([40, 50, 60, 70])

# %%
model = Sequential()
model.add(Dense(100, activation='relu', input_dim=3))
model.add(Dense(1))

# %%
model.compile(optimizer='sgd', loss='categorical_hinge')

# %%
model.fit(X, y, epochs=1000, verbose=0)

# %%
x_input = array([50,60,70])

# %%
x_input = x_input.reshape((1,3))

# %%
prediction = model.predict(x_input)

# %%
prediction
# Out:
# array([[69.030846]], dtype=float32)

# %%
import pandas as pd

# %%
data = pd.read_csv("MLP.csv")

# %%
data.shape
# Out:
# (365, 2)

# %%
data = data.dropna()

# %%
X = data.Date

# %%
y = data.Births

# %%
model = Sequential()
model.add(Dense(100, activation='relu', input_dim=3))
model.add(Dense(1))

# %%
model.compile(optimizer="sgd", loss="mse")

# %%
from sklearn.model_selection import train_test_split

# %%
prediction = model.predict(X_test)

# %%
X = pd.DataFrame()

# %%
for i in range(data.Date.shape[0]): 
    temp = (data.values[i][0].split("-"))
    X[i] = [temp[0], temp[1], temp[2]]

# %%
from sklearn.metrics import mean_absolute_error

# %%
X.T.shape
# Out:
# (365, 3)

# %%
X_train, X_test, y_train, y_test = train_test_split(X.T, y, train_size=0.7, random_state=42, shuffle=True)
# Out:
# D:\programs\Anaconda\lib\site-packages\sklearn\model_selection\_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
model.fit(X_train, y_train, epochs=1000)
# Out:
# Epoch 1/1000
# 255/255 [==============================] - 0s 47us/step - loss: 54.1929
# Epoch 2/1000
# 255/255 [==============================] - 0s 46us/step - loss: 54.1911
# Epoch 3/1000
# 255/255 [==============================] - 0s 52us/step - loss: 54.1742
# Epoch 4/1000
# 255/255 [==============================] - 0s 47us/step - loss: 54.1757
# Epoch 5/1000
# 255/255 [==============================] - 0s 47us/step - loss: 54.1867
# Epoch 6/1000
# 255/255 [==============================] - 0s 59us/step - loss: 54.1881
# Epoch 7/1000
# 255/255 [==============================] - 0s 78us/step - loss: 54.1617
# Epoch 8/1000
# 255/255 [==============================] - 0s 93us/step - loss: 54.1623
# Epoch 9/1000
# 255/255 [==============================] - 0s 91us/step - loss: 54.1730
# Epoch 10/1000
# 255/255 [==============================] - 0s 78us/step - loss: 54.1982
# Epoch 11/1000
# 255/255 [==============================] - 0s 70us/step - loss: 54.1720
# Epoch 12/1000
# ...

# %%
prediction = model.predict(X_test)

# %%
mean_absolute_error(prediction, y_test)
# Out:
# 5.519819571755149

# %%
y.describe()
# Out:
# count    365.000000
# mean      41.980822
# std        7.348257
# min       23.000000
# 25%       37.000000
# 50%       42.000000
# 75%       46.000000
# max       73.000000
# Name: Births, dtype: float64

# %%
1 - mean_absolute_error(prediction, y_test) / y.mean()
# Out:
# 0.8685156859824689

# %% [markdown]
# ### compare with smth simplier.... maiby SVR

# %%
from sklearn.svm import SVR

# %%
model_SVR = SVR()

# %%
model_SVR.fit(X_train, y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
prediction_SVR = model_SVR.predict(X_test)

# %%
1 - mean_absolute_error(prediction_SVR, y_test) / y.mean()
# Out:
# 0.8752341720392802

# %% [markdown]
#  ### try to improve  MLP

# %%
model_2 = Sequential()
model_2.add(Dense(200, activation='tanh', input_dim=3))
model_2.add(Dense(1))

# %%
model_2.compile(optimizer="adam", loss="mse")

# %%
model_2.fit(X_train, y_train, epochs=2000, verbose=1)
# Out:
# Epoch 1/2000
# 255/255 [==============================] - 1s 2ms/step - loss: 54.2298
# Epoch 2/2000
# 255/255 [==============================] - 0s 90us/step - loss: 54.1949
# Epoch 3/2000
# 255/255 [==============================] - 0s 93us/step - loss: 54.1694
# Epoch 4/2000
# 255/255 [==============================] - 0s 82us/step - loss: 54.2155
# Epoch 5/2000
# 255/255 [==============================] - 0s 90us/step - loss: 54.1683
# Epoch 6/2000
# 255/255 [==============================] - 0s 80us/step - loss: 54.1933
# Epoch 7/2000
# 255/255 [==============================] - 0s 66us/step - loss: 54.1673
# Epoch 8/2000
# 255/255 [==============================] - 0s 59us/step - loss: 54.1919
# Epoch 9/2000
# 255/255 [==============================] - 0s 59us/step - loss: 54.1888
# Epoch 10/2000
# 255/255 [==============================] - 0s 66us/step - loss: 54.2676
# Epoch 11/2000
# 255/255 [==============================] - 0s 59us/step - loss: 54.3376
# Epoch 12/2000
# ...

# %%
prediction_2 = model_2.predict(X_test)

# %%
1 - mean_absolute_error(prediction_2, y_test) / y.mean()
# Out:
# 0.8684137523413691
